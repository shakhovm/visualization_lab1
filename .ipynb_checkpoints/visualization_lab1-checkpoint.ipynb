# %%
import pandas as pd
import altair as alt

# %%
data_folder = "GLB.Ts_dSST.csv"
df = pd.read_csv(data_folder, skiprows=1)
df
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880 -0.29 -0.18 -0.11 -0.19 -0.11 -0.23 -0.21 -0.09 -0.16 -0.23 -0.20
# 1    1881 -0.15 -0.17  0.04  0.04  0.02 -0.20 -0.06 -0.02 -0.13 -0.20 -0.21
# 2    1882  0.15  0.15  0.04 -0.18 -0.16 -0.26 -0.20 -0.05 -0.10 -0.24 -0.16
# 3    1883 -0.31 -0.39 -0.13 -0.17 -0.20 -0.12 -0.08 -0.15 -0.20 -0.14 -0.22
# 4    1884 -0.15 -0.08 -0.37 -0.42 -0.36 -0.40 -0.34 -0.26 -0.27 -0.24 -0.30
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 133  2013  0.66  0.55  0.66  0.52  0.57  0.65  0.57  0.65  0.76  0.67  0.78
# 134  2014  0.73  0.52  0.76  0.77  0.85  0.66  0.56  0.80  0.88  0.81  0.66
# 135  2015  0.81  0.87  0.90  0.74  0.75  0.79  0.71  0.79  0.81  1.07  1.02
# 136  2016  1.15  1.34  1.30  1.07  0.90  0.78  0.82  0.99  0.87  0.89  0.90
# 137  2017  0.96  1.11  1.13  0.93  0.88  0.70  0.81  0.86  0.74  0.88  0.87
#
#       Dec   J-D   D-N   DJF   MAM   JJA   SON
# ...

# %%
domain_pd = df["Year"].unique()[::10]
points = alt.Chart(df).mark_point(filled=True, 
                         color='#ff7b45', 
                         size=90)

left_years = df[df["Year"].isin([1904, 1998])]
right_years = df[df["Year"].isin([1944, 2014, 2015, 2017])]
max_year = df[df["J-D"] == df["J-D"].max()]
mean_ = df[(df["Year"] >= 1880) & (df["Year"] <= 1899)]["J-D"].mean()
right_text_year = alt.Chart(right_years).mark_text(
    align='left',
    baseline='middle',
    dx=7
).encode(
    text='Year'
)

left_text_year = alt.Chart(left_years).mark_text(
    align='right',
    baseline='middle',
    dx=-7
).encode(
    text='Year'
)

text_max_year = alt.Chart(max_year).mark_text(
    align='left',
    baseline='middle',
    dx=7,
    fontWeight='bold'
).encode(
    text='Year'
)

line = alt.Chart({"values": [{"x": 1880, "y": mean_}, {"x": 2017, "y": mean_}]}).mark_line(color='gray'
).encode(
    x='x:O',
    y ='y:Q' 
)

hot_text = alt.Chart({"values": [{"x": 2010, "y": mean_}]}).mark_text(
    text=['HOTTER THAN THE','1880-1899 AVERAGE'], fontSize=13, dy=-30, dx=-11
).encode(
    x='x:O', y='y:Q'
)

cold_text = alt.Chart({"values": [{"x": 2010, "y": mean_}]}).mark_text(
    text=['COLDER'], fontSize=13, dy=15, dx=20
).encode(
    x='x:O', y='y:Q'
)

al = (points + right_text_year + left_text_year + text_max_year + hot_text + cold_text).encode(
    x = alt.X(field='Year', 
              type = 'ordinal',
              title = 'Year',
              axis=alt.Axis(values=domain_pd,  labelAngle=0, grid=True, labelOffset=10, labelPadding=10)
             
              ),
    y = alt.Y(field = 'J-D', 
              type = 'quantitative',
              title='Temperature'
              )
)

(line + al).properties(
    width = 950, height = 400, background = '#F9F9F9', padding = 25,
    title=alt.TitleParams(
        ['Annual Global Surface Temperature,', 'Relative to Late 19th Century Avarage'],
        dx = -330,
        dy = 60,
        fontSize=15
    ))
# Out:
# alt.LayerChart(...)
